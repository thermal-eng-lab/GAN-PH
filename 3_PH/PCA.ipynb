# %% [markdown]
# 2024.12.10(Tue)
# Principal component analysis for real and GAN-generated structures
# ---

# %%
import cv2
import numpy as np
import sys
import pandas as pd
import matplotlib.pyplot as plt
import os
import homcloud.interface as hc
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import pickle
import seaborn as sns

# ---- my modules ----  #
import PCA_func

# %%
plt.rcParams['font.family'] ='Times New Roman'#使用するフォント
plt.rcParams['xtick.direction'] = 'in'#x軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
plt.rcParams['ytick.direction'] = 'in'#y軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
plt.rcParams['xtick.major.width'] = 1.0#x軸主目盛り線の線幅
plt.rcParams['ytick.major.width'] = 1.0#y軸主目盛り線の線幅
plt.rcParams['font.size'] = 10.5 #フォントの大きさ
plt.rcParams['axes.linewidth'] = 1.0# 軸の線幅edge linewidth。囲みの太さ
plt.rcParams['axes.axisbelow'] = True
plt.rcParams['mathtext.fontset'] = 'cm'

# %%
# ------- hyperparameters ------- #
# 1. phases 
phases =  ["Ni", "YSZ", "Pore"]

# 2. resolution size
sizes = ["revised_030","revised_040","revised_050" ]

# 3. dimension of homologies
dims = ["Dim_0", "Dim_1", "Dim_2", "all"]

# %%
def PCA_analysis(size, phase, dim, out_folder):

    # ======= step.1 load saved vector ======= #
    # ----- load PI_vector(real) ----- #
    header = "../2_Persistence_Image/PIs/real/{}".format(size)
    df_vects_real = PCA_func.cat_dfs(header, phase, dim)

    # ----- load PI_vector(WGAN-generated) ----- #
    header = "../2_Persistence_Image/PIs/WGAN-generated/{}".format(size)
    df_vects_wgan = PCA_func.cat_dfs(header, phase, dim)

    # ----- load PI_vector(sphere-generated) ----- #
    header = "../2_Persistence_Image/PIs/sphere-generated/{}".format(size)
    df_vects_sphere = PCA_func.cat_dfs(header, phase, dim)

    # ======= step.2 PCA ======= #
    # ----- real ----- #
    ad_real = PCA_func.AnodesData(df_vects_real)
    df_pca_real, pca_reducer = PCA_func.calc_pca(ad_real,
                                                 n_components=40,
                                                 pca_reducer=None)

    os.makedirs(os.path.join(out_folder,"real/{}".format(phase)), exist_ok=True)
    df_pca_real.to_csv(
        os.path.join(out_folder,"real/{}/PCA_{}_real.csv".format(phase,dim)), index=False
    )
    with open(os.path.join(out_folder,"real/{}/PCA_reducer_{}.pkl".format(phase,dim)), "wb") as f:
        pickle.dump(pca_reducer, f)

    # ------ PCA for fake (WGAN-gp) data ------ #
    ad_wgan = PCA_func.AnodesData(df_vects_wgan)
    df_pca_wgan, _ = PCA_func.calc_pca(ad_wgan, 40, pca_reducer)

    os.makedirs(os.path.join(out_folder,"WGAN-generated/{}".format(phase)), exist_ok=True)
    df_pca_wgan.to_csv(
        os.path.join(out_folder,"WGAN-generated/{}/PCA_{}_fake.csv".format(phase,dim)), index=False
    )

    # ------ PCA for fake (sphere) data ------ #
    ad_sphere = PCA_func.AnodesData(df_vects_sphere)
    df_pca_sphere, _ = PCA_func.calc_pca(ad_sphere, 40, pca_reducer)

    os.makedirs(os.path.join(out_folder,"sphere-generated/{}".format(phase)), exist_ok=True)
    df_pca_sphere.to_csv(
        os.path.join(out_folder,"sphere-generated/{}/PCA_{}_sphere.csv".format(phase,dim)), index=False
    )

    return df_pca_real, df_pca_wgan, df_pca_sphere

# %%
for size in sizes:

    # output directory for calculated principal components
    out_folder = "./PCA_results/{}".format(size)
    os.makedirs(out_folder, exist_ok=True)

    for dim in dims:
        for phase in phases:
            print("size: {}, phase: {}, dim: {}".format(size, phase, dim))
            _, _, _ = PCA_analysis(size, phase, dim, out_folder)
            print("done \n ")
# Out:
# size: revised_030, phase: Ni, dim: Dim_0
# Cumulative explained variance ratio: 99.664%
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# done
#
# size: revised_030, phase: YSZ, dim: Dim_0
# Cumulative explained variance ratio: 99.999%
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# done
#
# size: revised_030, phase: Pore, dim: Dim_0
# Cumulative explained variance ratio: 99.999%
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# done
#
# size: revised_030, phase: Ni, dim: Dim_1
# Cumulative explained variance ratio: 99.996%
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# done
#
# size: revised_030, phase: YSZ, dim: Dim_1
# Cumulative explained variance ratio: 100.000%
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# done
#
# size: revised_030, phase: Pore, dim: Dim_1
# Cumulative explained variance ratio: 100.000%
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# done
#
# size: revised_030, phase: Ni, dim: Dim_2
# Cumulative explained variance ratio: 99.971%
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# done
#
# size: revised_030, phase: YSZ, dim: Dim_2
# Cumulative explained variance ratio: 99.887%
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# done
#
# size: revised_030, phase: Pore, dim: Dim_2
# Cumulative explained variance ratio: 99.993%
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# done
#
# size: revised_030, phase: Ni, dim: all
# Cumulative explained variance ratio: 99.647%
# Change of data shape: (1500, 2109) ---> (1500, 40)
# Change of data shape: (1500, 2109) ---> (1500, 40)
# Change of data shape: (1500, 2109) ---> (1500, 40)
# done
#
# size: revised_030, phase: YSZ, dim: all
# Cumulative explained variance ratio: 99.955%
# Change of data shape: (1500, 2109) ---> (1500, 40)
# Change of data shape: (1500, 2109) ---> (1500, 40)
# Change of data shape: (1500, 2109) ---> (1500, 40)
# done
#
# size: revised_030, phase: Pore, dim: all
# Cumulative explained variance ratio: 99.838%
# Change of data shape: (1500, 2109) ---> (1500, 40)
# Change of data shape: (1500, 2109) ---> (1500, 40)
# Change of data shape: (1500, 2109) ---> (1500, 40)
# done
#
# size: revised_040, phase: Ni, dim: Dim_0
# Cumulative explained variance ratio: 95.833%
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# done
#
# size: revised_040, phase: YSZ, dim: Dim_0
# Cumulative explained variance ratio: 99.638%
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# done
#
# size: revised_040, phase: Pore, dim: Dim_0
# Cumulative explained variance ratio: 99.687%
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# done
#
# size: revised_040, phase: Ni, dim: Dim_1
# Cumulative explained variance ratio: 99.807%
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# done
#
# size: revised_040, phase: YSZ, dim: Dim_1
# Cumulative explained variance ratio: 99.986%
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# done
#
# size: revised_040, phase: Pore, dim: Dim_1
# Cumulative explained variance ratio: 99.910%
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# done
#
# size: revised_040, phase: Ni, dim: Dim_2
# Cumulative explained variance ratio: 97.967%
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# done
#
# size: revised_040, phase: YSZ, dim: Dim_2
# Cumulative explained variance ratio: 97.014%
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# done
#
# size: revised_040, phase: Pore, dim: Dim_2
# Cumulative explained variance ratio: 98.203%
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# done
#
# size: revised_040, phase: Ni, dim: all
# Cumulative explained variance ratio: 96.198%
# Change of data shape: (1500, 2109) ---> (1500, 40)
# Change of data shape: (1500, 2109) ---> (1500, 40)
# Change of data shape: (1500, 2109) ---> (1500, 40)
# done
#
# size: revised_040, phase: YSZ, dim: all
# Cumulative explained variance ratio: 99.568%
# Change of data shape: (1500, 2109) ---> (1500, 40)
# Change of data shape: (1500, 2109) ---> (1500, 40)
# Change of data shape: (1500, 2109) ---> (1500, 40)
# done
#
# size: revised_040, phase: Pore, dim: all
# Cumulative explained variance ratio: 97.869%
# Change of data shape: (1500, 2109) ---> (1500, 40)
# Change of data shape: (1500, 2109) ---> (1500, 40)
# Change of data shape: (1500, 2109) ---> (1500, 40)
# done
#
# size: revised_050, phase: Ni, dim: Dim_0
# Cumulative explained variance ratio: 86.421%
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# done
#
# size: revised_050, phase: YSZ, dim: Dim_0
# Cumulative explained variance ratio: 97.504%
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# done
#
# size: revised_050, phase: Pore, dim: Dim_0
# Cumulative explained variance ratio: 97.422%
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# done
#
# size: revised_050, phase: Ni, dim: Dim_1
# Cumulative explained variance ratio: 97.493%
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# done
#
# size: revised_050, phase: YSZ, dim: Dim_1
# Cumulative explained variance ratio: 99.784%
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# done
#
# size: revised_050, phase: Pore, dim: Dim_1
# Cumulative explained variance ratio: 98.867%
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# done
#
# size: revised_050, phase: Ni, dim: Dim_2
# Cumulative explained variance ratio: 92.712%
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# done
#
# size: revised_050, phase: YSZ, dim: Dim_2
# Cumulative explained variance ratio: 92.610%
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# done
#
# size: revised_050, phase: Pore, dim: Dim_2
# Cumulative explained variance ratio: 96.351%
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# Change of data shape: (1500, 703) ---> (1500, 40)
# done
#
# size: revised_050, phase: Ni, dim: all
# Cumulative explained variance ratio: 85.329%
# Change of data shape: (1500, 2109) ---> (1500, 40)
# Change of data shape: (1500, 2109) ---> (1500, 40)
# Change of data shape: (1500, 2109) ---> (1500, 40)
# done
#
# size: revised_050, phase: YSZ, dim: all
# Cumulative explained variance ratio: 97.659%
# Change of data shape: (1500, 2109) ---> (1500, 40)
# Change of data shape: (1500, 2109) ---> (1500, 40)
# Change of data shape: (1500, 2109) ---> (1500, 40)
# done
#
# size: revised_050, phase: Pore, dim: all
# Cumulative explained variance ratio: 90.401%
# Change of data shape: (1500, 2109) ---> (1500, 40)
# Change of data shape: (1500, 2109) ---> (1500, 40)
# Change of data shape: (1500, 2109) ---> (1500, 40)
# done
